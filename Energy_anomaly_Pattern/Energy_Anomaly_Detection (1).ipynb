# %% [markdown]
# ## Libraries Used

# %% [markdown]
# #  Energy Anomaly Detection System
# ## AI-Powered Commercial Building Energy Intelligence
#
# ### Major Project Submission
#
# <br>**Evoastra Ventures Pvt Ltd** </br>
# **B.Tech – Artificial Intelligence & Machine Learning**
# **By: Ganesh Tarapure**
# Year: 2026
#
# ---
#
# ##  Problem Statement
#
# Commercial buildings consume nearly 30% of global energy, leading to significant operational costs.
# Unexpected spikes in energy consumption (anomalies) occur due to:
#
# - Equipment failure
# - HVAC inefficiency
# - Occupancy mismatch
# - Faulty sensors
#
# This project builds a Machine Learning pipeline to automatically:
#
# - Detect anomalies
# - Analyze peak anomaly hours
# - Estimate cost impact
# - Generate business recommendations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn.covariance import EllipticEnvelope

# %% [markdown]
# ## Python Libraries (Install via pip)
# <br>**pandas**        --   Data wrangling </br>
# <br>**numpy**         --   Numerical ops </br>
# <br>**scikit-learn**  --   ML algorithms </br>
#  <br>**matplotlib**   --   Visualization </br>
# <br>**seaborn**       --   Statistical plots</br>
# <br>**streamlit**     --   Dashboard </br>
# <br>**plotly**        --   Interactive viz </br>
