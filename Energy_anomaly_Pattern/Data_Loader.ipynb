# %% [markdown]
# ## Data Loader

# %% [markdown]
# ## data_loader.py
#
# ### What data_loader.py does?
#
# * Loads CSV file
#
# * Detects energy columns automatically
#
# * Ensures timestamp exists
#
# #### Why important ?
#
# Without clean loading → everything fails.

# %% [markdown]
# The load_data() function is responsible for data ingestion. It constructs the dataset file path dynamically, loads the CSV file into a pandas DataFrame, converts the timestamp column into datetime format for time-series analysis, and returns the structured dataset for further preprocessing and modeling.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# ## pandas
# Used for:
#
# * Reading CSV files
#
# * Handling tabular data
#
# * Data cleaning & transformation
#
# ##  os
#
# Used for:
#
# * Handling file paths
#
# * Making code cross-platform (Windows/Linux/Mac safe)

# %% [markdown]
# ## Function

# %%
def load_data(data_path):

# %% [markdown]
# * Loads a CSV dataset
# * Converts timestamp column to datetime format
# * Prints dataset size
# * Returns a pandas DataFrame
#
# It is the data ingestion module of your ML pipeline.

# %% [markdown]
# ## Print Status

# %%
 print(" Loading Data...")

# %% [markdown]
# Just a progress message in terminal.

# %% [markdown]
# ## Build File Path

# %%
file_path = os.path.join(data_path, "building_energy_800k.csv")

# %% [markdown]
# What this does:
#
# * It combines:
#
# data_path + filename Safely.
#
# * Instead of writing:
#
# "data/building_energy_800k.csv"
#
# * It automatically creates correct path:
#
# * Windows → data\building_energy_800k.csv
#
# * Linux/Mac → data/building_energy_800k.csv
#
# * This makes your code production-ready.

# %% [markdown]
# ## Read Csv File

# %%
df = pd.read_csv(file_path)

# %% [markdown]
# Loads CSV into a pandas DataFrame
#
# Stores it in variable df
#
# Now df contains:
#
# * timestamp
# * electricity
# * gas
# * water

# %% [markdown]
# ## Print

# %%
print("Raw Shape:", df.shape)

# %% [markdown]
# df.shape returns:
#
# (rows, columns)
#
# * Example:
#
# Raw Shape: (799664, 6)
#
# * Meaning:
#
# 799,664 rows
#
# 6 columns
#
# Very useful for debugging and validation.

# %% [markdown]
# ## Data Frame

# %%
    return df

# %% [markdown]
# Return DataFrame

# %% [markdown]
# ## Whole COde

# %%
import pandas as pd
import os

def load_data(data_path):

    print(" Loading Data...")

    file_path = os.path.join(data_path, "building_energy_800k.csv")
    df = pd.read_csv(file_path)

    
    print("Raw Shape:", df.shape)

    return df
