# %% [markdown]
# ## Visualization

# %% [markdown]
# Visualization.py

# %% [markdown]
# ### What this visualization.py do ?
# * Visualizes energy time-series
# * Highlights anomaly points
# * Saves professional graph
# * Ready for PDF report
# * Useful for business presentation

# %% [markdown]
# #### Information :

# %% [markdown]
# * This function generates a time-series visualization of electricity consumption and overlays detected anomaly points.
# *  It saves the output as a PNG image for documentation and reporting purposes.
# *  The scatter layer highlights abnormal energy spikes detected by the anomaly detection model.

# %% [markdown]
# ## Import Library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Imports Matplotlib
#
# plt is used to:
#
# Create graphs
#
# Customize them
#
# Save them

# %% [markdown]
# ## Function

# %%
def save_plots(df):

# %% [markdown]
# Function named save_plots
#
# Takes one input:
#
# df → DataFrame containing:
#
# timestamp
#
# electricity
#
# final_anomaly

# %% [markdown]
# ## Print Status

# %%
print("📈 Saving Visualizations...")
# Out:
# 📈 Saving Visualizations...

# %% [markdown]
# Just a progress message in console.

# %% [markdown]
# ## Create New Figure

# %%
plt.figure()

# %% [markdown]
# Creates a fresh empty graph
#
# Prevents overlap with previous plots

# %% [markdown]
# ## Plot Normal Energy Line

# %%
plt.plot(df["timestamp"], df["electricity"])

# %% [markdown]
# What it does:
#
# X-axis → timestamp
#
# Y-axis → electricity consumption
#
# Creates a continuous line graph
#
#  This shows overall energy usage trend.

# %% [markdown]
# ## Highlight Anomalies

# %%
plt.scatter(
    df[df["final_anomaly"]==1]["timestamp"],
    df[df["final_anomaly"]==1]["electricity"]
)

# %% [markdown]
# What happens here:
#
# * Step 1:
#
# df["final_anomaly"] == 1
#
# Selects only rows where anomaly is detected.
#
# * Step 2:
#
# Gets timestamps of anomalies
#
# Gets electricity values of anomalies
#
# * Step 3:
#
# Plots them as scatter points
#
# These appear as dots on the graph.
#
#  If you want them red (better visibility):
#
# plt.scatter(..., color="red")

# %% [markdown]
# ## Title

# %%
 plt.title("Energy with Anomalies")

# %% [markdown]
# Adding the Title to Graph

# %% [markdown]
# ## Save Png from Graph

# %%
plt.savefig("energy_anomalies.png")

# %% [markdown]
# Save Image File
#
#
# This:
#
# * Saves the graph
# * In your project directory
# * As a PNG image

# %% [markdown]
# ## Close Plot

# %%
 plt.close()

# %% [markdown]
# Important step.
#
# Why?
#
# * Frees memory
#
# * Prevents overlapping plots
#
# * Good practice for production systems

# %% [markdown]
# ## Final Print

# %%
 print("✅ Plots Saved")

# %% [markdown]
# Confirms saving complete.

# %% [markdown]
# ##  Whole Code

# %%
import matplotlib.pyplot as plt

def save_plots(df):

    print("📈 Saving Visualizations...")

    plt.figure()
    plt.plot(df["timestamp"], df["electricity"])
    plt.scatter(
        df[df["final_anomaly"]==1]["timestamp"],
        df[df["final_anomaly"]==1]["electricity"]
    )
    plt.title("Energy with Anomalies")
    plt.savefig("energy_anomalies.png")
    plt.close()

    print("✅ Plots Saved")
